# %% [markdown]
# #Kuis Responsi Kecerdasan Buatan Tahun Akademik 2022/2023
# 1. Silahkan akses dataset berikut https://raw.githubusercontent.com/adivii/datasets/main/Artificial%20Intelligence/Pertemuan%205/Wine_Quality_Data.csv
# 2. Lakukan Preprocessing pada data tersebut
# 3. Lakukan Feature Selection untuk membuat klasifikasi kualitas wine
# 4. Split data menjadi train dan test dengan proporsi 4:1
# 5. Buat model klasifikasi linear (metode bebas)
# 6. Hitung akurasi atau score dari model kalian (Minimal akurasi 60%)
# 7. Kumpulkan dalam bentuk link Google Colaboratory
# 8. Pengumpulan paling lambat 24 Maret 2022 pukul 23.59 (link pengumpulan menyusul)

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Akses data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/adivii/datasets/main/Artificial%20Intelligence/Pertemuan%205/Wine_Quality_Data.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# Preprocessing

# %%
# Feature Selection
y = df['quality']
df = df.drop('quality', axis=1)
df = df.drop('Id', axis=1)

# Hapus NaN
df = df.dropna()

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Split data
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=20)

# %% [markdown]
# Modeling

# %%
# Model klasifikasi linear menggunakan Logistic Regression
model = LogisticRegression()

# Buat model train set
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Prediksi menggunakan test set
pred = model.predict(x_test)

# %%
# Menghitung akurasi
accuracy = accuracy_score(y_test, pred)

print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.6244541484716157
